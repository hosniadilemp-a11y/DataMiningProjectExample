# %% [markdown]
# # 03 — Preprocessing & Feature Engineering Pipeline
# **Heart Disease Risk Prediction Reference Project**
# *Simulated Contributor: SIAD19*

# %%
import pandas as pdfrom src.preprocessing import prepare_data

# %% [markdown]
# ## 1. Execute Preprocessing Split

# %%
X_train, X_test, y_train, y_test, preprocessor, feature_names = prepare_data(save_artifacts=True)print(f'Train shape: {X_train.shape}, Test shape: {X_test.shape}')print('Total features:', len(feature_names))
