# %% [markdown]
# # 04 — Model Training, Tuning & Benchmark Evaluation
# **Heart Disease Risk Prediction Reference Project**
# *Simulated Contributor: SIAD19 / RSD20*

# %%
import pandas as pdimport joblibfrom src.utils import MODELS_DIR, DATA_PROCESSED

# %% [markdown]
# ## 1. Load Model Benchmark Results

# %%
comp_df = pd.read_csv(DATA_PROCESSED / 'model_comparison.csv')comp_df

# %% [markdown]
# ## 2. Load Best Model Artifact

# %%
best_model = joblib.load(MODELS_DIR / 'best_model.joblib')print('Best Model Class:', type(best_model))
