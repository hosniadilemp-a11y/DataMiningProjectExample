# %% [markdown]
# # 02 — Statistical Analysis & Hypothesis Testing Suite
# **Heart Disease Risk Prediction Reference Project**
# *Simulated Contributor: AISD05*

# %%
import pandas as pdfrom src.statistics import run_hypothesis_suite

# %% [markdown]
# ## 1. Run 6 Hypothesis Tests (FDR Corrected)

# %%
results = run_hypothesis_suite()stat_df = pd.DataFrame(results)stat_df[['id', 'test', 'statistic', 'p_value_raw', 'p_value_fdr', 'effect_size_type', 'effect_size_val']]
