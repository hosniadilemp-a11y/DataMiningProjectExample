# %% [markdown]
# # 02 — Data Preprocessing & Feature Engineering
# **Heart Disease Risk Prediction Reference Project**
# *Simulated Contributor: SIAD19*

# %%
import pandas as pdimport numpy as npimport joblibfrom src.preprocessing import prepare_data, add_engineered_features

# %% [markdown]
# ## 1. Domain Feature Engineering

# %%
df_sample = pd.DataFrame({    'cholesterol_total': [220, 180], 'hdl': [45, 55],    'resting_bp_systolic': [140, 120], 'resting_bp_diastolic': [90, 80]})feat_sample = add_engineered_features(df_sample)feat_sample

# %% [markdown]
# ## 2. Execute Leakage-Free Preprocessing Pipeline

# %%
X_train, X_test, y_train, y_test, preprocessor, feature_names = prepare_data(save_artifacts=True)print('Processed Feature Vector Length:', len(feature_names))print('Processed Train Shape:', X_train.shape)
