# %% [markdown]
# # 03 — Model Training, Tuning & Benchmark Evaluation
# **Heart Disease Risk Prediction Reference Project**
# *Simulated Contributor: SIAD19 / RSD20*

# %%
import pandas as pdimport joblibfrom src.utils import MODELS_DIR, DATA_PROCESSEDfrom src.models import train_and_optimize_allfrom src.evaluation import evaluate_all_models

# %% [markdown]
# ## 1. Load Processed Train/Test Sets

# %%
X_train = pd.read_csv(DATA_PROCESSED / 'X_train.csv')X_test = pd.read_csv(DATA_PROCESSED / 'X_test.csv')y_train = pd.read_csv(DATA_PROCESSED / 'y_train.csv').squeeze()y_test = pd.read_csv(DATA_PROCESSED / 'y_test.csv').squeeze()print(f'Train shape: {X_train.shape}, Test shape: {X_test.shape}')

# %% [markdown]
# ## 2. Load Model Comparison Benchmark

# %%
comp_df = pd.read_csv(DATA_PROCESSED / 'model_comparison.csv')comp_df

# %% [markdown]
# ## 3. Verify Saved Best Classifier

# %%
best_model = joblib.load(MODELS_DIR / 'best_model.joblib')print('Best Model Artifact:', type(best_model))
