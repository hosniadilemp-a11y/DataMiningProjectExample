# %% [markdown]
# # 01 — Exploratory Data Analysis & Quality Audit
# **Heart Disease Risk Prediction Reference Project**
# *Simulated Contributor: AISD05*

# %%
import pandas as pdimport numpy as npimport matplotlib.pyplot as pltimport seaborn as snsfrom scipy import statsfrom pathlib import Pathimport kagglehubplt.style.use('seaborn-v0_8-whitegrid' if 'seaborn-v0_8-whitegrid' in plt.style.available else 'default')

# %% [markdown]
# ## 1. Kaggle Dataset Acquisition & Schema Audit

# %%
# KaggleHub official fetchpath = kagglehub.dataset_download('uditjain13/heart-disease-risk-2026')print('Path to Kaggle dataset files:', path)csv_path = Path(path) / 'heart_disease_risk_2026.csv'df = pd.read_csv(csv_path)print(f'Shape: {df.shape[0]} rows, {df.shape[1]} columns')df.head(5)

# %% [markdown]
# ## 2. Missing Value & Data Quality Check

# %%
print('Total missing values:', df.isnull().sum().sum())print('Duplicate rows:', df.duplicated().sum())print('\nTarget Class Balance:')print(df['has_heart_disease'].value_counts(normalize=True))

# %% [markdown]
# ## 3. Exploratory Plots & Correlations

# %%
fig, ax = plt.subplots(figsize=(6, 4))sns.countplot(data=df, x='has_heart_disease', palette=['#2b5c8f', '#d95f02'], ax=ax)ax.set_title('Target Class Distribution (N=9,000)')plt.show()

# %% [markdown]
# ## 4. Statistical Testing (Mann-Whitney & Chi-Square)

# %%
# Mann-Whitney U test for ST Depressiong0 = df[df['has_heart_disease'] == 0]['st_depression']g1 = df[df['has_heart_disease'] == 1]['st_depression']stat, p = stats.mannwhitneyu(g0, g1)print(f'ST Depression Mann-Whitney U = {stat:.1f}, p-value = {p:.4e}')
