# %% [markdown]
# # 01 — Exploratory Data Analysis & Quality Audit
# **Heart Disease Risk Prediction Reference Project**
# *Simulated Contributor: AISD05*

# %%
import pandas as pdimport numpy as npimport matplotlib.pyplot as pltimport seaborn as snsimport kagglehubfrom pathlib import Pathplt.style.use('seaborn-v0_8-whitegrid' if 'seaborn-v0_8-whitegrid' in plt.style.available else 'default')

# %% [markdown]
# ## 1. Kaggle Dataset Fetch & Audit

# %%
path = kagglehub.dataset_download('uditjain13/heart-disease-risk-2026')print('Kaggle path:', path)df = pd.read_csv(Path(path) / 'heart_disease_risk_2026.csv')print(f'Shape: {df.shape[0]} rows, {df.shape[1]} columns')df.head(5)

# %% [markdown]
# ## 2. Quality & Missing Values Profile

# %%
print('Missing Values:', df.isnull().sum().sum())print('Duplicates:', df.duplicated().sum())print('Target Distribution:')print(df['has_heart_disease'].value_counts(normalize=True))
